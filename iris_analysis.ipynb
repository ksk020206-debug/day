# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
IRIS_CSV_PATH = '../data/Iris.csv'
IRIS_COLUMNS = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

# %%
import pandas

pandas.read_csv('../data/Iris.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 3
#       1 import pandas
#       2
# ----> 3 pandas.read_json('../data/Iris.csv')
#
# File c:\work\pexp2\.venv\Lib\site-packages\pandas\io\json\_json.py:853, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     851     return json_reader
#     852 else:
# --> 853     return json_reader.read()
#
# File c:\work\pexp2\.venv\Lib\site-packages\pandas\io\json\_json.py:989, in JsonReader.read(self)
#     987         obj = self._read_pyarrow()
#     988     elif self.engine == "ujson":
# --> 989         obj = self._read_ujson()
#     991 return obj
#
# ...

# %%
df = pd.read_csv(
    IRIS_CSV_PATH,
    skiprows=1,
    header=None,
    name=IRIS_COLUMNS
)

df.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df = pd.read_csv(
#       2     IRIS_CSV_PATH,
#       3     skiprows=1,
#       4     header=None,
#
# TypeError: 'str' object is not callable

# %%
df.head()
# Out:
#    0    1    2    3    4            5
# 0  1  5.1  3.5  1.4  0.2  Iris-setosa
# 1  2  4.9  3.0  1.4  0.2  Iris-setosa
# 2  3  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5  5.0  3.6  1.4  0.2  Iris-setosa

# %%
df.sample(frac=0.1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.sample(frac=0.1)
#
# NameError: name 'df' is not defined
